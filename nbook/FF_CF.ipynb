# %%
import numpy as np
import pandas as pd
sys.path.insert(0, '/Users/kent/data/python/')
from get_ff import get_ff

R_VW=get_ff('Portfolios_Formed_on_CF-P',key=0) # 0 is VW; 1 is EW
R_EW=get_ff('Portfolios_Formed_on_CF-P',key=1) # 0 is VW; 1 is EW
# Out:
# get_ff.py loaded
#
# Loading Data from file with Portfolios_Formed_on_CF-P, Description is:
#
# Portfolios Formed on CF-P
# -------------------------
#
# This file was created by CMPT_EP_CFP_OP_INV_NI_AC_RETS using the 202004 CRSP database. It contains value- and equal-weighted returns for portfolios formed on CF/P. The portfolios are constructed at the end of June. CF/P is cashflow (earnings before extraordinary plus deferred tax income statement plus common equitys share of depreciation) at the last fiscal year end of the prior calendar year divided by ME at the end of December of the prior year. Annual returns are from January to December. Missing data are indicated by -99.99 or -999. The break points include utilities and include financials. The portfolios include utilities and include financials. Copyright 2020 Kenneth R. French
#
#   0 : Value Weight Returns -- Monthly (826 rows x 19 cols)
#   1 : Equal Weight Returns -- Monthly (826 rows x 19 cols)
# ...

# %%
(1+(R_VW.iloc[:,-10:]/100.)).cumprod().plot(logy=True)

# %%
(1+(R_EW.iloc[:,-10:]/100.)).cumprod().plot(logy=True)

# %%
R_CF_Neg = pd.DataFrame({'VW':(R_VW.iloc[:,0]/100.),'EW':(R_EW.iloc[:,0]/100.)})
(1+R_CF_Neg).cumprod().plot(logy=True)
